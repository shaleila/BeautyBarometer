# %%
import requests
r = requests.get('http://features.peta.org/cruelty-free-company-search/cruelty_free_companies_search.aspx?Dotest=8')

# %%
r
# Out:
# <Response [200]>

# %%
print(r.text[0:500])
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
# <!--<![endif]-->
# <head profile="http://gmpg.org/xfn/11">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge">
# <meta name="apple-itunes-app" content="app-id=421236952 ">
# <meta http-equiv="Content-Type" content="text/html;

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(r.text)

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
# <!--<![endif]-->
# <head profile="http://gmpg.org/xfn/11">
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=421236952 " name="apple-itunes-app"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width" name="viewport"/>
# <link href="favicon.ico" rel="shortcut icon"/>
# <link href="images/apple-touch-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
# <link href="images/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="images/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml">
#  <!--<![endif]-->
#  <head profile="http://gmpg.org/xfn/11">
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=421236952 " name="apple-itunes-app"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="favicon.ico" rel="shortcut icon"/>
#   <link href="images/apple-touch-icon-180x180.png" rel="apple-touch-icon-precomposed" sizes="180x180"/>
#   <link href="images/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#   <link href="images/apple-touch-icon-144x144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/>
# ...
